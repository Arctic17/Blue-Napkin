# %% [markdown]
# # Flambage
# Valeur critique pour une force normal a une poutre.
#
# ## Formule
#
# **P cr ($F$)** : Newton [N] ($1 \text{ N} = 1 \text{ kg} \cdot \text{m/s}^2$).
#
#
# ## Limite d'applcation

# %%
import matplotlib.pyplot as plt
import sympy as sp
import numpy as np



Nc = np.pi
print (Nc)
# Out:
# 3.141592653589793
