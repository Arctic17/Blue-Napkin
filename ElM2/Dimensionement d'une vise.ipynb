# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sympy as sp
import scipy

# %% [markdown]
# Parametre de la vise

# %% [markdown]
# Calcule de couple requis

# %%
Cm=Faxial*Rmoy*tan(rho+gamma)
